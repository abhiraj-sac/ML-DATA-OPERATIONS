# %%
import seaborn as sb
import pandas as pd
import numpy as np
tips = sb.load_dataset('tips')
titanic = pd.read_csv('titanic.csv')
flight = sb.load_dataset('flights')
iris = sb.load_dataset('iris')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.scatterplot(data=tips, x="total_bill", y="tip",hue="sex",style='smoker',size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sb.barplot(data=titanic,x='Pclass',y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sb.boxplot(data=titanic,y='Age',x='Sex',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sb.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sb.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_4940\4262150110.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_4940\4262150110.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sb.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# (titanic.groupby('Pclass').mean()['Survived']*100).plot(kind="bar")
